# %%
import os

# %%
cpu = int(input("Choose CPU to run fib.py on. (0, 1)"))
nterms = int(input("How many terms? "))

os.system(f"taskset -c {cpu} python3 fib.py {nterms}")
# Out:
# Choose CPU to run fib.py on. (0, 1)1
# How many terms? 32
# time spent: 11.616465330123901
# 0
